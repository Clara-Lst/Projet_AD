# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('regularite-mensuelle-tgv-aqst.ods',engine='odf')

display( 
    data.head().style.background_gradient(cmap='BuPu')
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3819: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /opt/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3820: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_4e8e8_row0_col4 {
#   background-color: #dae7f1;
#   color: #000000;
# }
# #T_4e8e8_row0_col5 {
#   background-color: #cadbeb;
#   color: #000000;
# }
# #T_4e8e8_row0_col6, #T_4e8e8_row4_col12 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_4e8e8_row0_col7, #T_4e8e8_row0_col11, #T_4e8e8_row0_col15, #T_4e8e8_row0_col26, #T_4e8e8_row0_col27, #T_4e8e8_row1_col7, #T_4e8e8_row1_col11, #T_4e8e8_row1_col15, #T_4e8e8_row1_col26, #T_4e8e8_row1_col27, #T_4e8e8_row2_col7, #T_4e8e8_row2_col11, #T_4e8e8_row2_col15, #T_4e8e8_row2_col26, #T_4e8e8_row2_col27, #T_4e8e8_row3_col7, #T_4e8e8_row3_col11, #T_4e8e8_row3_col15, #T_4e8e8_row3_col26, #T_4e8e8_row3_col27, #T_4e8e8_row4_col7, #T_4e8e8_row4_col11, #T_4e8e8_row4_col15, #T_4e8e8_row4_col26, #T_4e8e8_row4_col27 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4e8e8_row0_col8 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_4e8e8_row0_col9, #T_4e8e8_row3_col4 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_4e8e8_row0_col10, #T_4e8e8_row1_col20, #T_4e8e8_row2_col20, #T_4e8e8_row3_col20 {
#   background-color: #93a5ce;
#   color: #f1f1f1;
# }
# #T_4e8e8_row0_col12 {
#   background-color: #e9f2f7;
#   color: #000000;
# }
# #T_4e8e8_row0_col13, #T_4e8e8_row0_col24 {
#   background-color: #8c90c3;
#   color: #f1f1f1;
# }
# #T_4e8e8_row0_col14, #T_4e8e8_row0_col18, #T_4e8e8_row0_col20, #T_4e8e8_row0_col23, #T_4e8e8_row0_col25, #T_4e8e8_row1_col5, #T_4e8e8_row1_col6, #T_4e8e8_row1_col8, #T_4e8e8_row1_col9, #T_4e8e8_row1_col12, #T_4e8e8_row1_col13, #T_4e8e8_row1_col16, #T_4e8e8_row1_col17, #T_4e8e8_row1_col18, #T_4e8e8_row1_col19, #T_4e8e8_row1_col21, #T_4e8e8_row1_col24, #T_4e8e8_row1_col25, #T_4e8e8_row2_col4, #T_4e8e8_row2_col6, #T_4e8e8_row2_col18, #T_4e8e8_row2_col22, #T_4e8e8_row2_col24, #T_4e8e8_row3_col6, #T_4e8e8_row3_col18, #T_4e8e8_row4_col10, #T_4e8e8_row4_col18 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_4e8e8_row0_col16, #T_4e8e8_row1_col10 {
#   background-color: #e3eef5;
#   color: #000000;
# }
# #T_4e8e8_row0_col17 {
#   background-color: #9ebcda;
#   color: #000000;
# }
# #T_4e8e8_row0_col19, #T_4e8e8_row4_col19 {
#   background-color: #d2e2ee;
#   color: #000000;
# }
# #T_4e8e8_row0_col21, #T_4e8e8_row1_col4, #T_4e8e8_row1_col22, #T_4e8e8_row1_col23, #T_4e8e8_row2_col13, #T_4e8e8_row2_col17, #T_4e8e8_row3_col5, #T_4e8e8_row3_col8, #T_4e8e8_row3_col9, #T_4e8e8_row3_col10, #T_4e8e8_row3_col12, #T_4e8e8_row3_col14, #T_4e8e8_row3_col16, #T_4e8e8_row3_col19, #T_4e8e8_row3_col25, #T_4e8e8_row4_col6, #T_4e8e8_row4_col20, #T_4e8e8_row4_col24 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_4e8e8_row0_col22 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_4e8e8_row1_col14 {
#   background-color: #670864;
#   color: #f1f1f1;
# }
# #T_4e8e8_row2_col5 {
#   background-color: #d9e6f1;
#   color: #000000;
# }
# #T_4e8e8_row2_col8 {
#   background-color: #eef5f9;
#   color: #000000;
# }
# #T_4e8e8_row2_col9 {
#   background-color: #650762;
#   color: #f1f1f1;
# }
# #T_4e8e8_row2_col10 {
#   background-color: #a2bfdb;
#   color: #000000;
# }
# #T_4e8e8_row2_col12 {
#   background-color: #e4eef5;
#   color: #000000;
# }
# #T_4e8e8_row2_col14 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_4e8e8_row2_col16 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_4e8e8_row2_col19 {
#   background-color: #cfdfed;
#   color: #000000;
# }
# #T_4e8e8_row2_col21 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_4e8e8_row2_col23 {
#   background-color: #ccddec;
#   color: #000000;
# }
# #T_4e8e8_row2_col25 {
#   background-color: #8c91c4;
#   color: #f1f1f1;
# }
# #T_4e8e8_row3_col13 {
#   background-color: #98b0d3;
#   color: #000000;
# }
# #T_4e8e8_row3_col17 {
#   background-color: #8b61ac;
#   color: #f1f1f1;
# }
# #T_4e8e8_row3_col21 {
#   background-color: #a7c2dd;
#   color: #000000;
# }
# #T_4e8e8_row3_col22 {
#   background-color: #8c81bc;
#   color: #f1f1f1;
# }
# #T_4e8e8_row3_col23 {
#   background-color: #adc7e0;
#   color: #000000;
# }
# #T_4e8e8_row3_col24 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_4e8e8_row4_col4 {
#   background-color: #c0d4e6;
#   color: #000000;
# }
# #T_4e8e8_row4_col5 {
#   background-color: #bcd1e5;
#   color: #000000;
# }
# #T_4e8e8_row4_col8 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_4e8e8_row4_col9 {
#   background-color: #8c79b8;
#   color: #f1f1f1;
# }
# #T_4e8e8_row4_col13 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_4e8e8_row4_col14 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_4e8e8_row4_col16 {
#   background-color: #cddeec;
#   color: #000000;
# }
# #T_4e8e8_row4_col17 {
#   background-color: #d1e1ee;
#   color: #000000;
# }
# #T_4e8e8_row4_col21 {
#   background-color: #96abd1;
#   color: #f1f1f1;
# }
# #T_4e8e8_row4_col22 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_4e8e8_row4_col23 {
#   background-color: #deeaf3;
#   color: #000000;
# }
# #T_4e8e8_row4_col25 {
#   background-color: #832088;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e8e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e8e8_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_4e8e8_level0_col1" class="col_heading level0 col1" >Service</th>
#       <th id="T_4e8e8_level0_col2" class="col_heading level0 col2" >Gare de départ</th>
#       <th id="T_4e8e8_level0_col3" class="col_heading level0 col3" >Gare d'arrivée</th>
#       <th id="T_4e8e8_level0_col4" class="col_heading level0 col4" >Durée moyenne du trajet</th>
#       <th id="T_4e8e8_level0_col5" class="col_heading level0 col5" >Nombre de circulations prévues</th>
#       <th id="T_4e8e8_level0_col6" class="col_heading level0 col6" >Nombre de trains annulés</th>
#       <th id="T_4e8e8_level0_col7" class="col_heading level0 col7" >Commentaire annulations</th>
#       <th id="T_4e8e8_level0_col8" class="col_heading level0 col8" >Nombre de trains en retard au départ</th>
#       <th id="T_4e8e8_level0_col9" class="col_heading level0 col9" >Retard moyen des trains en retard au départ</th>
#       <th id="T_4e8e8_level0_col10" class="col_heading level0 col10" >Retard moyen de tous les trains au départ</th>
#       <th id="T_4e8e8_level0_col11" class="col_heading level0 col11" >Commentaire retards au départ</th>
#       <th id="T_4e8e8_level0_col12" class="col_heading level0 col12" >Nombre de trains en retard à l'arrivée</th>
#       <th id="T_4e8e8_level0_col13" class="col_heading level0 col13" >Retard moyen des trains en retard à l'arrivée</th>
#       <th id="T_4e8e8_level0_col14" class="col_heading level0 col14" >Retard moyen de tous les trains à l'arrivée</th>
#       <th id="T_4e8e8_level0_col15" class="col_heading level0 col15" >Commentaire retards à l'arrivée</th>
#       <th id="T_4e8e8_level0_col16" class="col_heading level0 col16" >Nombre trains en retard > 15min</th>
#       <th id="T_4e8e8_level0_col17" class="col_heading level0 col17" >Retard moyen trains en retard > 15 (si liaison concurrencée par vol)</th>
#       <th id="T_4e8e8_level0_col18" class="col_heading level0 col18" >Nombre trains en retard > 30min</th>
#       <th id="T_4e8e8_level0_col19" class="col_heading level0 col19" >Nombre trains en retard > 60min</th>
#       <th id="T_4e8e8_level0_col20" class="col_heading level0 col20" >Prct retard pour causes externes</th>
#       <th id="T_4e8e8_level0_col21" class="col_heading level0 col21" >Prct retard pour cause infrastructure</th>
#       <th id="T_4e8e8_level0_col22" class="col_heading level0 col22" >Prct retard pour cause gestion trafic</th>
#       <th id="T_4e8e8_level0_col23" class="col_heading level0 col23" >Prct retard pour cause matériel roulant</th>
#       <th id="T_4e8e8_level0_col24" class="col_heading level0 col24" >Prct retard pour cause gestion en gare et réutilisation de matériel</th>
#       <th id="T_4e8e8_level0_col25" class="col_heading level0 col25" >Prct retard pour cause prise en compte voyageurs (affluence</th>
#       <th id="T_4e8e8_level0_col26" class="col_heading level0 col26" > gestions PSH</th>
#       <th id="T_4e8e8_level0_col27" class="col_heading level0 col27" > correspondances)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e8e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id=

# %% [markdown]
# Ici on enleve les colonnes

# %%
cols_to_drop = [
    c for c in data.columns 
    if c.startswith("Commentaire") 
    or " gestions PSH" in c 
    or "correspondances)" in c
]
data = data.drop(columns=cols_to_drop)
display(
    data.head().style.background_gradient(cmap="BuPu")
)
len(data)
# Out:
# <style type="text/css">
# #T_d5846_row0_col4 {
#   background-color: #dae7f1;
#   color: #000000;
# }
# #T_d5846_row0_col5 {
#   background-color: #cadbeb;
#   color: #000000;
# }
# #T_d5846_row0_col6, #T_d5846_row4_col10 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_d5846_row0_col7 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_d5846_row0_col8, #T_d5846_row3_col4 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_d5846_row0_col9, #T_d5846_row1_col17, #T_d5846_row2_col17, #T_d5846_row3_col17 {
#   background-color: #93a5ce;
#   color: #f1f1f1;
# }
# #T_d5846_row0_col10 {
#   background-color: #e9f2f7;
#   color: #000000;
# }
# #T_d5846_row0_col11, #T_d5846_row0_col21 {
#   background-color: #8c90c3;
#   color: #f1f1f1;
# }
# #T_d5846_row0_col12, #T_d5846_row0_col15, #T_d5846_row0_col17, #T_d5846_row0_col20, #T_d5846_row0_col22, #T_d5846_row1_col5, #T_d5846_row1_col6, #T_d5846_row1_col7, #T_d5846_row1_col8, #T_d5846_row1_col10, #T_d5846_row1_col11, #T_d5846_row1_col13, #T_d5846_row1_col14, #T_d5846_row1_col15, #T_d5846_row1_col16, #T_d5846_row1_col18, #T_d5846_row1_col21, #T_d5846_row1_col22, #T_d5846_row2_col4, #T_d5846_row2_col6, #T_d5846_row2_col15, #T_d5846_row2_col19, #T_d5846_row2_col21, #T_d5846_row3_col6, #T_d5846_row3_col15, #T_d5846_row4_col9, #T_d5846_row4_col15 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_d5846_row0_col13, #T_d5846_row1_col9 {
#   background-color: #e3eef5;
#   color: #000000;
# }
# #T_d5846_row0_col14 {
#   background-color: #9ebcda;
#   color: #000000;
# }
# #T_d5846_row0_col16, #T_d5846_row4_col16 {
#   background-color: #d2e2ee;
#   color: #000000;
# }
# #T_d5846_row0_col18, #T_d5846_row1_col4, #T_d5846_row1_col19, #T_d5846_row1_col20, #T_d5846_row2_col11, #T_d5846_row2_col14, #T_d5846_row3_col5, #T_d5846_row3_col7, #T_d5846_row3_col8, #T_d5846_row3_col9, #T_d5846_row3_col10, #T_d5846_row3_col12, #T_d5846_row3_col13, #T_d5846_row3_col16, #T_d5846_row3_col22, #T_d5846_row4_col6, #T_d5846_row4_col17, #T_d5846_row4_col21 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_d5846_row0_col19 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_d5846_row1_col12 {
#   background-color: #670864;
#   color: #f1f1f1;
# }
# #T_d5846_row2_col5 {
#   background-color: #d9e6f1;
#   color: #000000;
# }
# #T_d5846_row2_col7 {
#   background-color: #eef5f9;
#   color: #000000;
# }
# #T_d5846_row2_col8 {
#   background-color: #650762;
#   color: #f1f1f1;
# }
# #T_d5846_row2_col9 {
#   background-color: #a2bfdb;
#   color: #000000;
# }
# #T_d5846_row2_col10 {
#   background-color: #e4eef5;
#   color: #000000;
# }
# #T_d5846_row2_col12 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_d5846_row2_col13 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_d5846_row2_col16 {
#   background-color: #cfdfed;
#   color: #000000;
# }
# #T_d5846_row2_col18 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_d5846_row2_col20 {
#   background-color: #ccddec;
#   color: #000000;
# }
# #T_d5846_row2_col22 {
#   background-color: #8c91c4;
#   color: #f1f1f1;
# }
# #T_d5846_row3_col11 {
#   background-color: #98b0d3;
#   color: #000000;
# }
# #T_d5846_row3_col14 {
#   background-color: #8b61ac;
#   color: #f1f1f1;
# }
# #T_d5846_row3_col18 {
#   background-color: #a7c2dd;
#   color: #000000;
# }
# #T_d5846_row3_col19 {
#   background-color: #8c81bc;
#   color: #f1f1f1;
# }
# #T_d5846_row3_col20 {
#   background-color: #adc7e0;
#   color: #000000;
# }
# #T_d5846_row3_col21 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_d5846_row4_col4 {
#   background-color: #c0d4e6;
#   color: #000000;
# }
# #T_d5846_row4_col5 {
#   background-color: #bcd1e5;
#   color: #000000;
# }
# #T_d5846_row4_col7 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_d5846_row4_col8 {
#   background-color: #8c79b8;
#   color: #f1f1f1;
# }
# #T_d5846_row4_col11 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_d5846_row4_col12 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_d5846_row4_col13 {
#   background-color: #cddeec;
#   color: #000000;
# }
# #T_d5846_row4_col14 {
#   background-color: #d1e1ee;
#   color: #000000;
# }
# #T_d5846_row4_col18 {
#   background-color: #96abd1;
#   color: #f1f1f1;
# }
# #T_d5846_row4_col19 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_d5846_row4_col20 {
#   background-color: #deeaf3;
#   color: #000000;
# }
# #T_d5846_row4_col22 {
#   background-color: #832088;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d5846">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5846_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_d5846_level0_col1" class="col_heading level0 col1" >Service</th>
#       <th id="T_d5846_level0_col2" class="col_heading level0 col2" >Gare de départ</th>
#       <th id="T_d5846_level0_col3" class="col_heading level0 col3" >Gare d'arrivée</th>
#       <th id="T_d5846_level0_col4" class="col_heading level0 col4" >Durée moyenne du trajet</th>
#       <th id="T_d5846_level0_col5" class="col_heading level0 col5" >Nombre de circulations prévues</th>
#       <th id="T_d5846_level0_col6" class="col_heading level0 col6" >Nombre de trains annulés</th>
#       <th id="T_d5846_level0_col7" class="col_heading level0 col7" >Nombre de trains en retard au départ</th>
#       <th id="T_d5846_level0_col8" class="col_heading level0 col8" >Retard moyen des trains en retard au départ</th>
#       <th id="T_d5846_level0_col9" class="col_heading level0 col9" >Retard moyen de tous les trains au départ</th>
#       <th id="T_d5846_level0_col10" class="col_heading level0 col10" >Nombre de trains en retard à l'arrivée</th>
#       <th id="T_d5846_level0_col11" class="col_heading level0 col11" >Retard moyen des trains en retard à l'arrivée</th>
#       <th id="T_d5846_level0_col12" class="col_heading level0 col12" >Retard moyen de tous les trains à l'arrivée</th>
#       <th id="T_d5846_level0_col13" class="col_heading level0 col13" >Nombre trains en retard > 15min</th>
#       <th id="T_d5846_level0_col14" class="col_heading level0 col14" >Retard moyen trains en retard > 15 (si liaison concurrencée par vol)</th>
#       <th id="T_d5846_level0_col15" class="col_heading level0 col15" >Nombre trains en retard > 30min</th>
#       <th id="T_d5846_level0_col16" class="col_heading level0 col16" >Nombre trains en retard > 60min</th>
#       <th id="T_d5846_level0_col17" class="col_heading level0 col17" >Prct retard pour causes externes</th>
#       <th id="T_d5846_level0_col18" class="col_heading level0 col18" >Prct retard pour cause infrastructure</th>
#       <th id="T_d5846_level0_col19" class="col_heading level0 col19" >Prct retard pour cause gestion trafic</th>
#       <th id="T_d5846_level0_col20" class="col_heading level0 col20" >Prct retard pour cause matériel roulant</th>
#       <th id="T_d5846_level0_col21" class="col_heading level0 col21" >Prct retard pour cause gestion en gare et réutilisation de matériel</th>
#       <th id="T_d5846_level0_col22" class="col_heading level0 col22" >Prct retard pour cause prise en compte voyageurs (affluence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5846_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5846_row0_col0" class="data row0 col0" >2025-01</td>
#       <td id="T_d5846_row0_col1" class="data row0 col1" >International</td>
#       <td id="T_d5846_row0_col2" class="data row0 col2" >GENEVE</td>
#       <td id="T_d5846_row0_col3" class="data row0 col3" >PARIS LYON</td>
#       <td id="T_d5846_row0_col4" class="data row0 col4" >193</td>
#       <td id="T_d5846_row0_col5" class="data row0 col5" >238</td>
#       <td id="T_d5846_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_d5846_row0_col7" class="data row0 col7" >216</td>
#       <td id="T_d5846_row0_col8" class="data row0 col8" >3.182485</td>
#       <td id="T_d5846_row0_col9" class="data row0 col9" >2.979606</td>
#       <td id="T_d5846_row0_col10" class="data row0 col10" >19</td>
#       <td id="T_d5846_row0_col11" class="data row0 col11" >42.776316</td>
#       <td id="T_d5846_row0_col12" class="data row0 col12" >4.399015</td>
#       <td id="T_d5846_row0_col13" class="data row0 col13" >19</td>
#       <td id="T_d5846_row0_col14" class="data row0 col14" >42.776316</td>
#       <td id="T_d5846_row0_col15"
# 1505

# %%
data=data.dropna()
len(data)
# Out:
# 1505
